# %%
a = [1,2,3,4]

# %%
type(a)
# Out:
# list

# %%
with open('number.txt','w') as f:
    for item in a:
        f.write(f'{item*2}\n')

# %%
with open('number.txt','r') as f:
    new_a=[ int(item.strip()) for item in f]

# %%
type(new_a)
# Out:
# list

# %%
print(new_a)
# Out:
# [2, 4, 6, 8]

# %%
with open('number.csv','r') as f1:
    a1 = [ int(n.strip()) for n in f1]

# %%
print(a1)
# Out:
# [1, 2, 3, 4]

# %%
import numpy as np

# %%
a2 = np.array(a1)

# %%
a2.shape
# Out:
# (4,)
