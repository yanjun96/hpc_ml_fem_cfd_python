# %%
# Docker Leearning

# %%
docker pull  xx

docker run xx

docker images

docker ps -a
# shows you all containers that are currently running.

docker rm xxxxxx xxxxx
# remove container

docker rm $(docker ps -a -q -f status=exited)
# remove all or
docker container prune
# Out:
#   Cell In[2], line 1
#     docker run
#            ^
# SyntaxError: invalid syntax

# %% [markdown]
# docker: package an application into a standardised unit
#
# images: blueprints of the application
#
# containers: isolation of virtual machines, deployed easily and consistently, created from images
#
#
# docker daemon: background service of docker containers
#
# docker client: interact with daemon
#
# docker hub: registry of docker images

# %%
images:  Base Child, Official, User images

# %%
dockerfile: a text file containing commands


FROM Python:3.8

WORKDIR /usr/src/app

COPY . .

RUN pip install --no-cache-dir -r requirements.txt

# %%
docker -t yanjun/catnip .
