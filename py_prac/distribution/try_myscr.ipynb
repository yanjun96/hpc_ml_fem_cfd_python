# %%
import my_scr
# Out:
# Hello!
# it is not main

# %%
my_scr.greet()
# Out:
# Hello!

# %%
import pdb

# %%
s = [1,2,3]
(pdb) s
# Out:
#   Cell In[4], line 2
#     (pdb) s
#           ^
# SyntaxError: invalid syntax
