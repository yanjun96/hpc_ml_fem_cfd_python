# %%
# https://keras.io/examples/timeseries/timeseries_classification_from_scratch/

# %%
import keras
print(keras.__version__)
# Out:
# 3.9.0

# %%
import keras
import numpy as np
import matplotlib.pyplot as plt

# %%
def readucr(filename):
    data = np.loadtxt(filename, delimiter="\t")
    y = data[:,0]
    x = data[:, 1:]
    return x, y.astype(int)

root_url = "https://raw.githubusercontent.com/hfawaz/cd-diagram/master/FordA/"

x_train, y_train = readucr(root_url + "FordA_TRAIN.tsv")
x_test, y_test = readucr(root_url + "FordA_TEST.tsv")

# %%
data = np.loadtxt(root_url + "FordA_TRAIN.tsv")
print(data.shape)
# Out:
# (3601, 501)

# %%
type(x_train)
# Out:
# numpy.ndarray

# %%
x_train.shape
# Out:
# (3601, 500)

# %%
y_train.shape
# Out:
# (3601,)

# %%
print(y_train)
# Out:
# [-1  1 -1 ... -1  1 -1]

# %%
print(x_train)
# Out:
# [[-0.79717168 -0.66439208 -0.37301463 ... -0.66439208 -1.0737958
#   -1.5643427 ]
#  [ 0.80485472  0.63462859  0.37347448 ... -0.71488505 -0.56044294
#   -0.31908642]
#  [ 0.7279851   0.11128392 -0.49912439 ...  0.39446303  0.33940042
#    0.25539062]
#  ...
#  [-0.57005428 -0.33316523 -0.29351853 ... -1.3937145  -0.94273327
#   -0.27072168]
#  [ 2.0067321   2.0791499   2.0220362  ... -0.43214504 -0.44123126
#   -0.28070891]
#  [-0.12524091 -0.32536268 -0.48823697 ...  0.55576053  0.57445102
#    0.57311598]]

# %%
print(y_train)
print(y_train.shape)
# Out:
# [-1  1 -1 ... -1  1 -1]
# (3601,)

# %%
classes = np.unique(np.concatenate((y_train, y_test), axis=0))

plt.figure()
for c in classes:
    c_x_train = x_train[y_train == c]
    plt.plot(c_x_train[0], label="class " + str(c))

plt.legend(loc="best")
plt.show()
plt.close()

# %%
print(classes)
print(classes.shape)
# Out:
# [-1  1]
# (2,)

# %%
x_train = x_train.reshape((x_train.shape[0], x_train.shape[1], 1))
x_test = x_test.reshape((x_test.shape[0], x_test.shape[1], 1))

# %%
x_train.shape
# Out:
# (3601, 500, 1)

# %%
num_classes = len(np.unique(y_train))
print(num_classes)
# Out:
# 2

# %%
idx = np.random.permutation(len(x_train))
x_train = x_train[idx]
y_train = y_train[idx]

# %%
y_train[y_train == -1] = 0
y_test[y_test == -1] = 0

# %%
print(idx)
# Out:
# [2089 1183 2741 ...  852 1776  846]

# %%
def make_model(input_shape):
    input_layer = keras.layers.Input(input_shape)

    conv1 = keras.layers.Conv1D(filters=64, kernel_size=3, padding="same")(input_layer)
    conv1 = keras.layers.BatchNormalization()(conv1)
    conv1 = keras.layers.ReLU()(conv1)

    conv2 = keras.layers.Conv1D(filters=64, kernel_size=3, padding="same")(conv1)
    conv2 = keras.layers.BatchNormalization()(conv2)
    conv2 = keras.layers.ReLU()(conv2)

    conv3 = keras.layers.Conv1D(filters=64, kernel_size=3, padding="same")(conv2)
    conv3 = keras.layers.BatchNormalization()(conv3)
    conv3 = keras.layers.ReLU()(conv3)

    gap = keras.layers.GlobalAveragePooling1D()(conv3)

    output_layer = keras.layers.Dense(num_classes, activation="softmax")(gap)

    return keras.models.Model(inputs=input_layer, outputs=output_layer)


model = make_model(input_shape=x_train.shape[1:])
keras.utils.plot_model(model, show_shapes=True)
# Out:
# You must install graphviz (see instructions at https://graphviz.gitlab.io/download/) for `plot_model` to work.

# %%
epochs = 50
batch_size = 32

callbacks = [
    keras.callbacks.ModelCheckpoint(
        "best_model.keras", save_best_only=True, monitor="val_loss"
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.5, patience=20, min_lr=0.0001
    ),
    keras.callbacks.EarlyStopping(monitor="val_loss", patience=50, verbose=1),
]
model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["sparse_categorical_accuracy"],
)
history = model.fit(
    x_train,
    y_train,
    batch_size=batch_size,
    epochs=epochs,
    callbacks=callbacks,
    validation_split=0.2,
    verbose=1,
)
# Out:
# Epoch 1/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.6091 - sparse_categorical_accuracy: 0.6268 - val_loss: 0.7575 - val_sparse_categorical_accuracy: 0.4938 - learning_rate: 0.0010
# Epoch 2/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.4621 - sparse_categorical_accuracy: 0.7815 - val_loss: 0.7499 - val_sparse_categorical_accuracy: 0.4938 - learning_rate: 0.0010
# Epoch 3/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.4450 - sparse_categorical_accuracy: 0.7661 - val_loss: 0.7294 - val_sparse_categorical_accuracy: 0.3939 - learning_rate: 0.0010
# Epoch 4/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.4403 - sparse_categorical_accuracy: 0.7817 - val_loss: 0.7429 - val_sparse_categorical_accuracy: 0.4688 - learning_rate: 0.0010
# Epoch 5/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.4277 - sparse_categorical_accuracy: 0.7846 - val_loss: 0.7559 - val_sparse_categorical_accuracy: 0.5298 - learning_rate: 0.0010
# Epoch 6/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.4138 - sparse_categorical_accuracy: 0.7922 - val_loss: 0.7544 - val_sparse_categorical_accuracy: 0.6117 - learning_rate: 0.0010
# Epoch 7/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.3955 - sparse_categorical_accuracy: 0.8185 - val_loss: 0.4710 - val_sparse_categorical_accuracy: 0.7836 - learning_rate: 0.0010
# Epoch 8/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.4062 - sparse_categorical_accuracy: 0.7920 - val_loss: 0.5949 - val_sparse_categorical_accuracy: 0.7074 - learning_rate: 0.0010
# Epoch 9/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.3855 - sparse_categorical_accuracy: 0.8056 - val_loss: 0.3540 - val_sparse_categorical_accuracy: 0.8516 - learning_rate: 0.0010
# Epoch 10/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.3746 - sparse_categorical_accuracy: 0.8219 - val_loss: 0.3712 - val_sparse_categorical_accuracy: 0.8336 - learning_rate: 0.0010
# Epoch 11/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.3809 - sparse_categorical_accuracy: 0.8160 - val_loss: 0.3233 - val_sparse_categorical_accuracy: 0.8530 - learning_rate: 0.0010
# Epoch 12/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.3926 - sparse_categorical_accuracy: 0.8116 - val_loss: 0.3847 - val_sparse_categorical_accuracy: 0.7906 - learning_rate: 0.0010
# Epoch 13/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.3609 - sparse_categorical_accuracy: 0.8352 - val_loss: 0.3454 - val_sparse_categorical_accuracy: 0.8141 - learning_rate: 0.0010
# Epoch 14/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.3443 - sparse_categorical_accuracy: 0.8557 - val_loss: 0.5509 - val_sparse_categorical_accuracy: 0.7212 - learning_rate: 0.0010
# Epoch 15/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.3631 - sparse_categorical_accuracy: 0.8330 - val_loss: 0.2872 - val_sparse_categorical_accuracy: 0.8807 - learning_rate: 0.0010
# Epoch 16/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.3309 - sparse_categorical_accuracy: 0.8504 - val_loss: 0.3909 - val_sparse_categorical_accuracy: 0.8100 - learning_rate: 0.0010
# Epoch 17/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.3067 - sparse_categorical_accuracy: 0.8822 - val_loss: 0.2874 - val_sparse_categorical_accuracy: 0.8918 - learning_rate: 0.0010
# Epoch 18/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.3038 - sparse_categorical_accuracy: 0.8654 - val_loss: 0.8924 - val_sparse_categorical_accuracy: 0.5908 - learning_rate: 0.0010
# Epoch 19/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.3259 - sparse_categorical_accuracy: 0.8433 - val_loss: 0.3347 - val_sparse_categorical_accuracy: 0.8322 - learning_rate: 0.0010
# Epoch 20/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.3123 - sparse_categorical_accuracy: 0.8623 - val_loss: 0.3317 - val_sparse_categorical_accuracy: 0.8433 - learning_rate: 0.0010
# Epoch 21/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.3106 - sparse_categorical_accuracy: 0.8671 - val_loss: 0.6077 - val_sparse_categorical_accuracy: 0.7129 - learning_rate: 0.0010
# Epoch 22/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.3130 - sparse_categorical_accuracy: 0.8654 - val_loss: 0.2652 - val_sparse_categorical_accuracy: 0.8946 - learning_rate: 0.0010
# Epoch 23/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.3014 - sparse_categorical_accuracy: 0.8689 - val_loss: 0.2994 - val_sparse_categorical_accuracy: 0.8350 - learning_rate: 0.0010
# Epoch 24/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.3083 - sparse_categorical_accuracy: 0.8645 - val_loss: 0.2683 - val_sparse_categorical_accuracy: 0.8863 - learning_rate: 0.0010
# Epoch 25/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.2994 - sparse_categorical_accuracy: 0.8781 - val_loss: 0.2636 - val_sparse_categorical_accuracy: 0.8960 - learning_rate: 0.0010
# Epoch 26/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.2725 - sparse_categorical_accuracy: 0.8950 - val_loss: 0.2756 - val_sparse_categorical_accuracy: 0.8932 - learning_rate: 0.0010
# Epoch 27/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.2713 - sparse_categorical_accuracy: 0.8895 - val_loss: 0.2462 - val_sparse_categorical_accuracy: 0.9001 - learning_rate: 0.0010
# Epoch 28/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.2813 - sparse_categorical_accuracy: 0.8768 - val_loss: 0.4604 - val_sparse_categorical_accuracy: 0.7462 - learning_rate: 0.0010
# Epoch 29/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.2659 - sparse_categorical_accuracy: 0.8843 - val_loss: 0.2724 - val_sparse_categorical_accuracy: 0.8918 - learning_rate: 0.0010
# Epoch 30/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.2489 - sparse_categorical_accuracy: 0.8984 - val_loss: 0.2866 - val_sparse_categorical_accuracy: 0.8918 - learning_rate: 0.0010
# Epoch 31/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.2651 - sparse_categorical_accuracy: 0.8906 - val_loss: 0.4435 - val_sparse_categorical_accuracy: 0.7712 - learning_rate: 0.0010
# Epoch 32/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.2623 - sparse_categorical_accuracy: 0.8847 - val_loss: 0.3558 - val_sparse_categorical_accuracy: 0.8211 - learning_rate: 0.0010
# Epoch 33/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.2580 - sparse_categorical_accuracy: 0.8943 - val_loss: 0.3932 - val_sparse_categorical_accuracy: 0.7989 - learning_rate: 0.0010
# Epoch 34/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.2959 - sparse_categorical_accuracy: 0.8793 - val_loss: 0.3187 - val_sparse_categorical_accuracy: 0.8266 - learning_rate: 0.0010
# Epoch 35/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.2551 - sparse_categorical_accuracy: 0.8966 - val_loss: 1.2470 - val_sparse_categorical_accuracy: 0.6352 - learning_rate: 0.0010
# Epoch 36/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.2453 - sparse_categorical_accuracy: 0.9008 - val_loss: 0.3044 - val_sparse_categorical_accuracy: 0.8474 - learning_rate: 0.0010
# Epoch 37/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.2509 - sparse_categorical_accuracy: 0.8958 - val_loss: 0.2978 - val_sparse_categorical_accuracy: 0.8405 - learning_rate: 0.0010
# Epoch 38/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.2340 - sparse_categorical_accuracy: 0.9052 - val_loss: 0.3837 - val_sparse_categorical_accuracy: 0.8072 - learning_rate: 0.0010
# Epoch 39/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.2338 - sparse_categorical_accuracy: 0.9041 - val_loss: 0.2524 - val_sparse_categorical_accuracy: 0.8960 - learning_rate: 0.0010
# Epoch 40/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.2342 - sparse_categorical_accuracy: 0.9077 - val_loss: 0.2325 - val_sparse_categorical_accuracy: 0.9043 - learning_rate: 0.0010
# Epoch 41/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.2205 - sparse_categorical_accuracy: 0.9082 - val_loss: 0.2488 - val_sparse_categorical_accuracy: 0.8821 - learning_rate: 0.0010
# Epoch 42/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.2262 - sparse_categorical_accuracy: 0.9048 - val_loss: 0.1932 - val_sparse_categorical_accuracy: 0.9112 - learning_rate: 0.0010
# Epoch 43/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.2046 - sparse_categorical_accuracy: 0.9233 - val_loss: 0.4261 - val_sparse_categorical_accuracy: 0.7864 - learning_rate: 0.0010
# Epoch 44/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.1800 - sparse_categorical_accuracy: 0.9385 - val_loss: 0.1858 - val_sparse_categorical_accuracy: 0.9293 - learning_rate: 0.0010
# Epoch 45/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.1739 - sparse_categorical_accuracy: 0.9388 - val_loss: 0.1698 - val_sparse_categorical_accuracy: 0.9320 - learning_rate: 0.0010
# Epoch 46/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.1896 - sparse_categorical_accuracy: 0.9362 - val_loss: 0.2076 - val_sparse_categorical_accuracy: 0.9279 - learning_rate: 0.0010
# Epoch 47/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.1580 - sparse_categorical_accuracy: 0.9445 - val_loss: 0.1843 - val_sparse_categorical_accuracy: 0.9168 - learning_rate: 0.0010
# Epoch 48/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.1534 - sparse_categorical_accuracy: 0.9467 - val_loss: 0.3141 - val_sparse_categorical_accuracy: 0.8391 - learning_rate: 0.0010
# Epoch 49/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.1519 - sparse_categorical_accuracy: 0.9509 - val_loss: 0.3004 - val_sparse_categorical_accuracy: 0.8419 - learning_rate: 0.0010
# Epoch 50/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.1369 - sparse_categorical_accuracy: 0.9642 - val_loss: 3.0622 - val_sparse_categorical_accuracy: 0.5631 - learning_rate: 0.0010

# %%
model = keras.models.load_model("best_model.keras")

test_loss, test_acc = model.evaluate(x_test, y_test)

print("Test accuracy", test_acc)
print("Test loss", test_loss)
# Out:
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1788 - sparse_categorical_accuracy: 0.9362
# Test accuracy 0.9318181872367859
# Test loss 0.18616974353790283

# %%
metric = "sparse_categorical_accuracy"
plt.figure()
plt.plot(history.history[metric])
plt.plot(history.history["val_" + metric])
plt.title("model " + metric)
plt.ylabel(metric, fontsize="large")
plt.xlabel("epoch", fontsize="large")
plt.legend(["train", "val"], loc="best")
plt.show()
plt.close()

# %%
type(history)
# Out:
# keras.src.callbacks.history.History
