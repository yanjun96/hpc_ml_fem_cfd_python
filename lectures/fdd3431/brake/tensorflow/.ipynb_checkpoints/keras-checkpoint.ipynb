# %%
import tensorflow as tf
print('TensorFlow version: ', tf.__version__)
# Out:
# TensorFlow version:  2.19.0

# %%
mnist = tf.keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train, y_train = x_train / 255.0, x_test / 255.0
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape = (28, 28)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(10)
])
# Out:
# /Users/yanjun/Documents/apps/miniconda3/envs/dd2421/lib/python3.10/site-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
predictions = model(x_train[:1]).numpy()
predictions
# Out:
# array([[-0.3619545 , -0.22420824, -0.40913737, -0.16640258, -0.54453707,
#          0.26465243,  0.5526677 , -0.91777277, -0.6647078 , -0.14336878]],
#       dtype=float32)

# %%
tf.nn.softmax(predictions).numpy()
# Out:
# array([[0.08281932, 0.09505044, 0.07900243, 0.1007068 , 0.0689981 ,
#         0.1549757 , 0.20670313, 0.04750539, 0.06118537, 0.10305338]],
#       dtype=float32)

# %%
loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)

# %%
loss_fn(y_train[:1], predictions).numpy()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 loss_fn(y_train[:1], predictions).numpy()
#
# File ~/Documents/apps/miniconda3/envs/dd2421/lib/python3.10/site-packages/keras/src/losses/loss.py:67, in Loss.__call__(self, y_true, y_pred, sample_weight)
#      60 y_pred = tree.map_structure(
#      61     lambda x: ops.convert_to_tensor(x, dtype=self.dtype), y_pred
#      62 )
#      63 y_true = tree.map_structure(
#      64     lambda x: ops.convert_to_tensor(x, dtype=self.dtype), y_true
#      65 )
# ---> 67 losses = self.call(y_true, y_pred)
#      68 out_mask = backend.get_keras_mask(losses)
#      70 if in_mask is not None and out_mask is not None:
#
# File ~/Documents/apps/miniconda3/envs/dd2421/lib/python3.10/site-packages/keras/src/losses/losses.py:33, in LossFunctionWrapper.call(self, y_true, y_pred)
#      31 y_true = tree.map_structure_up_to(y_true, lambda x: x[0], y_true_y_pred)
#      32 y_pred = tree.map_structure_up_to(y_pred, lambda x: x[1], y_true_y_pred)
# ---> 33 return self.fn(y_true, y_pred, **self._fn_kwargs)
#
# File ~/Documents/apps/miniconda3/envs/dd2421/lib/python3.10/site-packages/keras/src/losses/losses.py:2246, in sparse_categorical_crossentropy(y_true, y_pred, from_logits, ignore_class, axis)
#    2241     y_true = y_true * ops.cast(valid_mask, y_true.dtype)
#    2242     y_pred = y_pred * ops.cast(
#    2243         ops.expand_dims(valid_mask, -1), y_pred.dtype
#    2244     )
# -> 2246 res = ops.sparse_categorical_crossentropy(
#    2247     y_true,
#    2248     y_pred,
#    2249     from_logits=from_logits,
#    2250     axis=axis,
#    2251 )
#    2253 if ignore_class is not None:
#    2254     valid_mask = ops.reshape(valid_mask, res_shape)
#
# File ~/Documents/apps/miniconda3/envs/dd2421/lib/python3.10/site-packages/keras/src/ops/nn.py:1964, in sparse_categorical_crossentropy(target, output, from_logits, axis)
#    1960 if any_symbolic_tensors((target, output)):
#    1961     return SparseCategoricalCrossentropy(
#    1962         from_logits=from_logits, axis=axis
#    1963     ).symbolic_call(target, output)
# -> 1964 return backend.nn.sparse_categorical_crossentropy(
#    1965     target, output, from_logits=from_logits, axis=axis
#    1966 )
#
# File ~/Documents/apps/miniconda3/envs/dd2421/lib/python3.10/site-packages/keras/src/backend/tensorflow/nn.py:725, in sparse_categorical_crossentropy(target, output, from_logits, axis)
#     719     raise ValueError(
#     720         "Argument `output` must be at least rank 1. "
#     721         "Received: "
#     722         f"output.shape={output.shape}"
#     723     )
#     724 if len(target.shape) != len(output.shape[:-1]):
# --> 725     raise ValueError(
#     726         "Argument `output` must have rank (ndim) `target.ndim - 1`. "
#     727         "Received: "
#     728         f"target.shape={target.shape}, output.shape={output.shape}"
#     729     )
#     730 for e1, e2 in zip(target.shape, output.shape[:-1]):
#     731     if e1 is not None and e2 is not None and e1 != e2:
#
# ValueError: Argument `output` must have rank (ndim) `target.ndim - 1`. Received: target.shape=(1, 28, 28), output.shape=(1, 10)

# %%
d
