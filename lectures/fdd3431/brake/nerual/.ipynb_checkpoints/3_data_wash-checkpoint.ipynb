# %%
# this file is used to sacle down the trianing data. 
# Original each sample contains 43644 data and the total braking time is 49 s, so the frequency is nearly 1000 Hz.
# New data has extracted as around 1 Hz, which means each second has one temperature data.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df_x = pd.read_csv('x.csv')
x = df_x.values
df_y = pd.read_csv('y.csv')
y = df_y.values
# Out:
# /home/yanjun/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "

# %%
print(x.shape)
# Out:
# (12, 130993)

# %%
x4 = np.delete(x, 0, axis = 1)
X = x4.reshape(12, 43664, 3)
y4 = np.delete(y, 0 , axis =1)
Y = y4.reshape(12, 43664, 1)

# %%
len(X[1])
#print(X[1])
# Out:
# 43664

# %%
plt.plot(Y[1])

# %%
X.shape
# Out:
# (12, 43664, 3)

# %%
x5 = (X[:,::100,:] )

# %%
x5.shape
# Out:
# (12, 437, 3)

# %%
y5 = Y[:,::100,:]

# %%
plt.plot(y5[1,:,:])

# %%
y5.shape
# Out:
# (12, 437, 1)
